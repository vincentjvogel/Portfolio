# %% [markdown]
# # Movie Project

# %%
# Import libraries
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 8) # adjust configuration of the plots

pd.set_option('display.max_rows', None)


# Read in data
df = pd.read_csv('/Users/vincentvogel/Desktop/new_me/sample_data/movies.csv')

# %% [markdown]
# ### Clean the Data

# %%
# Look at the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Check for missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print(f'{col} - {pct_missing}%')
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Since it would be very difficult to find the missing data, 
# we will remove all rows with missing data
df = df[~df.isnull().any(axis=1)]


# Double check that we no longer have missing data using the same code from above
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print(f'{col} - {pct_missing}%')
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Look at data types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Change some columns to appropriate data type
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')


df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# It looks like some of the years in 'realeased' don't match the years in'year'
# I will make a separate column with the year in 'released'
x = df['released'].str.split(',', expand=True)
df['year_correct'] = x[1].str[1:5]


df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Look for duplicates and drop them
df.pivot_table(columns=['name'], aggfunc='size').sort_values(ascending=False).head(50)
# Out:
# name
# Hercules                           3
# The Lion King                      2
# The Avengers                       2
# A Nightmare on Elm Street          2
# Pet Sematary                       2
# Hellboy                            2
# Legend                             2
# Footloose                          2
# Heat                               2
# Unforgettable                      2
# Nobody's Fool                      2
# The Hunted                         2
# Crash                              2
# Death at a Funeral                 2
# No Good Deed                       2
# The Thing                          2
# No Escape                          2
# Flatliners                         2
# Under Suspicion                    2
# Anna Karenina                      2
# Rush                               2
# Life                               2
# The Postman                        2
# Annie                              2
# Bad Company                        2
# ...

# %%
df.loc[df['name'] == 'Hercules']
# Out:
#           name rating      genre  year                         released  \
# 406   Hercules     PG  Adventure  1983  August 26, 1983 (United States)
# 3062  Hercules      G  Animation  1997    June 27, 1997 (United States)
# 6469  Hercules  PG-13     Action  2014    July 25, 2014 (United States)
#
#       score     votes      director          writer            star  \
# 406     4.0    3600.0   Luigi Cozzi     Luigi Cozzi    Lou Ferrigno
# 3062    7.3  212000.0  Ron Clements    Ron Clements    Tate Donovan
# 6469    6.0  149000.0  Brett Ratner  Ryan J. Condal  Dwayne Johnson
#
#             country     budget      gross               company  runtime  \
# 406           Italy    2500000   10676194     Cannon Films Inc.     98.0
# 3062  United States   85000000  252712101  Walt Disney Pictures     93.0
# 6469  United States  100000000  244819862    Paramount Pictures     98.0
#
#      year_correct
# 406          1983
# 3062         1997
# 6469         2014

# %% [markdown]
# - It looks like there are re-releases
# - No duplicates

# %% [markdown]
# ### Find Correlations

# %%
# Look at highest gross income
df = df.sort_values(by=['gross'], inplace=False, ascending=False)
df.head(10)
# Out:
#                                             name rating      genre  year  \
# 5445                                      Avatar  PG-13     Action  2009
# 7445                           Avengers: Endgame  PG-13     Action  2019
# 3045                                     Titanic  PG-13      Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                      Avengers: Infinity War  PG-13     Action  2018
# 7480                               The Lion King     PG  Animation  2019
# 6653                              Jurassic World  PG-13     Action  2015
# 6043                                The Avengers  PG-13     Action  2012
# 6646                                   Furious 7  PG-13     Action  2015
# 7494                                   Frozen II     PG  Animation  2019
#
#                                released  score      votes         director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0    James Cameron
# ...

# %%
# Test to see if budget and company to have a high correlation to gross income
# Build scatter plot budget vs gross revenue
plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs. Gross Revenue')

plt.xlabel('Budget')
plt.ylabel('Gross Revenue')


plt.show()

# %%
# Plot budget vs gross using seaborn
sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"red"}, line_kws={"color":"black"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %% [markdown]
# - It looks like there is a high correlation between budget and gross revenue

# %%
# Want to look at whether or not company has a correlation with gross revenue
df_numerized = df.copy()

for col_name in df_numerized:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category').cat.codes

df_numerized.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
#
#       star  country     budget       gross  company  runtime  year_correct
# 5445  1534       47  237000000  2847246203     1382    162.0            29
# 7445  1470       47  356000000  2797501328      983    181.0            39
# 3045  1073       47  200000000  2201647264     1382    194.0            17
# 6663   356       47  245000000  2069521700      945    138.0            35
# 7244  1470       47  321000000  2048359754      983    149.0            38

# %%
# Define a correlation matrix
corr_matrix = df_numerized.corr(method='pearson')


# Create visualizatin for correlation matrix
sns.heatmap(corr_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Columns')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
# Unstack
corr_pairs = corr_matrix.unstack()
corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.029234
#               genre           0.010996
#               year            0.025542
#               released       -0.006152
#               score           0.014450
#               votes           0.012615
#               director        0.015246
#               writer          0.012880
#               star           -0.006882
#               country        -0.025490
#               budget          0.023392
#               gross           0.005639
#               company         0.021697
#               runtime         0.010850
#               year_correct    0.026759
# rating        name           -0.029234
#               rating          1.000000
#               genre           0.147796
#               year            0.019499
#               released        0.018083
#               score           0.065983
#               votes           0.006031
#               director        0.014656
# ...

# %%
# Sorted
sorted_pairs = corr_pairs.sort_values()
sorted_pairs[(sorted_pairs > 0.5) & (sorted_pairs < 1.0)]
# Out:
# votes         gross           0.614751
# gross         votes           0.614751
#               budget          0.740247
# budget        gross           0.740247
# year_correct  year            0.996723
# year          year_correct    0.996723
# dtype: float64

# %% [markdown]
# - I originally thought that company would have a high correlation with gross income but that is not the case
# - Looking at the information above, we can see that only budget and votes have a high correlation with gross income
