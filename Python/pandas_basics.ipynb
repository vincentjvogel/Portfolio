# %% [markdown]
# # Pandas Basics

# %% [markdown]
# <br>
# ## 1. Read in csv, excel, and txt

# %%
import pandas as pd

## CSV
df = pd.read_csv('/Users/vincentvogel/Desktop/new_me/sample_data/pokemon_data.csv')
#print(df.head(4))
#print(df.tail(4))

# %%
## EXCEL
df_xlsx = pd.read_excel('/Users/vincentvogel/Desktop/new_me/sample_data/pokemon_data.xlsx')
#print(df_xlsx.head(3))

# %%
## TXT
df_txt = pd.read_csv('/Users/vincentvogel/Desktop/new_me/sample_data/pokemon_data.txt', delimiter='\t')
#print(df_txt.head(2))

# %% [markdown]
# <br><br>
# ***
# <br>
# ## 2. Read Headers, Columns, Rows, and Specific Locations

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### *Get a specific column*

# %%
print(df['Name']) # you can also do df.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# ### *Get first 5 names*

# %%
print(df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %% [markdown]
# ### *Include only specific columns*

# %%
print(df[['Name', 'Type 1', 'Type 2', 'HP']])
# Out:
#                       Name   Type 1  Type 2  HP
# 0                Bulbasaur    Grass  Poison  45
# 1                  Ivysaur    Grass  Poison  60
# 2                 Venusaur    Grass  Poison  80
# 3    VenusaurMega Venusaur    Grass  Poison  80
# 4               Charmander     Fire     NaN  39
# ..                     ...      ...     ...  ..
# 795                Diancie     Rock   Fairy  50
# 796    DiancieMega Diancie     Rock   Fairy  50
# 797    HoopaHoopa Confined  Psychic   Ghost  80
# 798     HoopaHoopa Unbound  Psychic    Dark  80
# 799              Volcanion     Fire   Water  80
#
# [800 rows x 4 columns]

# %% [markdown]
# ### *Gets all the data from row 1*

# %%
print(df.iloc[1])
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %% [markdown]
# ### *Get rows 1-4*

# %%
print(df.iloc[1:5])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### *Gets the index and name for all rows*

# %%
#for index, row in df.iterrows():
#    print(index, row['Name'])

# %% [markdown]
# ### *Gets all fire type pokemon*

# %%
df.loc[df['Type 1'] == "Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# 135  126                     Magmar   Fire       NaN   65      95       57
# 147  136                    Flareon   Fire       NaN   65     130       60
# 158  146                    Moltres   Fire    Flying   90     100       90
# 169  155                  Cyndaquil   Fire       NaN   39      52       43
# 170  156                    Quilava   Fire       NaN   58      64       58
# 171  157                 Typhlosion   Fire       NaN   78      84       78
# 236  218                     Slugma   Fire       NaN   40      40       40
# 237  219                   Magcargo   Fire      Rock   50      50      120
# 259  240                      Magby   Fire       NaN   45      75       37
# 263  244                      Entei   Fire       NaN  115     115       85
# 270  250                      Ho-oh   Fire    Flying  106     130       90
# 276  255                    Torchic   Fire       NaN   45      60       40
# 277  256                  Combusken   Fire  Fighting   60      85       60
# 278  257                   Blaziken   Fire  Fighting   80     120       70
# 279  257      BlazikenMega Blaziken   Fire  Fighting   80     160       80
# 352  322                      Numel   Fire    Ground   60      60       40
# 353  323                   Camerupt   Fire    Ground   70     100       70
# 354  323      CameruptMega Camerupt   Fire    Ground   70     120      100
# 355  324                    Torkoal   Fire       NaN   70      85      140
# 435  390                   Chimchar   Fire       NaN   44      58       44
# 436  391                   Monferno   Fire  Fighting   64      78       52
# 437  392                  Infernape   Fire  Fighting   76     104       71
# 518  467                  Magmortar   Fire       NaN   75      95       67
# 542  485                    Heatran   Fire     Steel   91      90      106
# 557  498                      Tepig   Fire       NaN   65      63       45
# 558  499                    Pignite   Fire  Fighting   90      93       55
# 559  500                     Emboar   Fire  Fighting  110     123       65
# 572  513                    Pansear   Fire       NaN   50      53       48
# 573  514                   Simisear   Fire       NaN   75      98       63
# 614  554                   Darumaka   Fire       NaN   70      90       45
# 615  555    DarmanitanStandard Mode   Fire       NaN  105     140       55
# 616  555         DarmanitanZen Mode   Fire   Psychic  105      30      105
# 692  631                    Heatmor   Fire       NaN   85      97       66
# 721  653                   Fennekin   Fire       NaN   40      45       40
# 722  654                    Braixen   Fire       NaN   59      59       58
# 723  655                    Delphox   Fire   Psychic   75      69       72
# 730  662                Fletchinder   Fire    Flying   62      73       55
# 731  663                 Talonflame   Fire    Flying   78      81       71
# 735  667                     Litleo   Fire    Normal   62      50       58
# 736  668                     Pyroar   Fire    Normal   86      68       72
# 799  721                  Volcanion   Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4         60       50     65           1      False
# 5         80       65     80           1      False
# 6        109       85    100           1      False
# 7        130       85    100           1      False
# 8        159      115    100           1      False
# 42        50       65     65           1      False
# 43        81      100    100           1      False
# 63        70       50     60           1      False
# 64       100       80     95           1      False
# 83        65       65     90           1      False
# 84        80       80    105           1      False
# 135      100       85     93           1      False
# 147       95      110     65           1      False
# 158      125       85     90           1       True
# 169       60       50     65           2      False
# 170       80       65     80           2      False
# 171      109       85    100           2      False
# 236       70       40     20           2      False
# 237       80       80     30           2      False
# 259       70       55     83           2      False
# 263       90       75    100           2       True
# 270      110      154     90           2       True
# 276       70       50     45           3      False
# 277       85       60     55           3      False
# 278      110       70     80           3      False
# 279      130       80    100           3      False
# 352       65       45     35           3      False
# 353      105       75     40           3      False
# 354      145      105     20           3      False
# 355       85       70     20           3      False
# 435       58       44     61           4      False
# 436       78       52     81           4      False
# 437      104       71    108           4      False
# 518      125       95     83           4      False
# 542      130      106     77           4       True
# 557       45       45     45           5      False
# 558       70       55     55           5      False
# 559      100       65     65           5      False
# 572       53       48     64           5      False
# 573       98       63    101           5      False
# 614       15       45     50           5      False
# 615       30       55     95           5      False
# 616      140      105     55           5      False
# 692      105       66     65           5      False
# 721       62       60     60           6      False
# 722       90       70     73           6      False
# 723      114      100    104           6      False
# 730       56       52     84           6      False
# 731       74       69    126           6      False
# 735       73       54     72           6      False
# 736      109       66    106           6      False
# 799      130       90     70           6       True

# %% [markdown]
# ### *Specific location (R,C)*

# %%
print(df.iloc[2,1]) # row 2 column 1
# Out:
# Venusaur

# %% [markdown]
# <br><br>
# ***
# <br>
# ## 3. Sorting/Describing Data

# %% [markdown]
# ### *Get the mean, std, and other stats from each column*

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %% [markdown]
# ### *Sorts pokemon alphabetically (descending)*

# %%
df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794       81       95     95           6       True
# 695       65       70     58           5      False
# 46        30       40     55           1      False
# 631       80       40     65           5      False
# 632      120       60    105           5      False
# ..       ...      ...    ...         ...        ...
# 393      115       60    115           3      False
# 392       75       60     75           3      False
# 68       105       55     90           1      False
# 511      132      105     30           4      False
# 510       92       85     60           4      False
#
# [800 rows x 12 columns]

# %% [markdown]
# ### *Sort multiple columns each with different ascending/descending values*

# %%
df.sort_values(['Type 1', 'HP'], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 520      116       56     95           4      False
# 698      135      105    100           5      False
# 231       40       95     85           2      False
# 232       40      105     75           2      False
# 678      100       60    145           5      False
# ..       ...      ...    ...         ...        ...
# 106       25       25     50           1      False
# 125       70       25     60           1      False
# 129       70       55     85           1      False
# 139       15       20     80           1      False
# 381       10       55     80           3      False
#
# [800 rows x 12 columns]

# %% [markdown]
# <br><br>
# ***
# <br>
# ## 4. Making Changes to the Data

# %% [markdown]
# ### *Make a new column*

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1) # axis=0 will sum vertically
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %% [markdown]
# ### *Delete/Drop a column*

# %%
#df = df.drop(columns=['Total'])
#df.head(5)

# %% [markdown]
# ### *Change the order of columns*

# %%
cols = list(df.columns.values)
df = df[cols[0:10] + [cols[-1]] + cols[10:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Total  Generation  Legendary
# 0       65     45    318           1      False
# 1       80     60    405           1      False
# 2      100     80    525           1      False
# 3      120     80    625           1      False
# 4       50     65    309           1      False

# %% [markdown]
# <br><br>
# ***
# <br>
# ## 5. Exporting Data into Desired Format

# %%
df.to_csv('/Users/vincentvogel/Desktop/new_me/Python/Pandas/basics/modified_pokemon_data.csv', index=False)
df.to_excel('/Users/vincentvogel/Desktop/new_me/Python/Pandas/basics/modified_pokemon_data.xlsx', index=False)
df.to_csv('/Users/vincentvogel/Desktop/new_me/Python/Pandas/basics/modified_pokemon_data.txt', index=False, sep='\t')

# %% [markdown]
# <br><br>
# ***
# <br>
# ## 6. Filtering Data

# %% [markdown]
# ### *Get the rows with specific conditions and export it*

# %%
grass_poison = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)] 
grass_poison.to_csv('/Users/vincentvogel/Desktop/new_me/Python/Pandas/basics/filtered.csv')

# %% [markdown]
# ### *Reset the index and get rid of old indeces*

# %%
grass_poison.reset_index(drop=True, inplace=True) #inplace saves these changes to the data frame 
grass_poison
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    3               Venusaur  Grass  Poison   80      82       83      100
# 1    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2   45              Vileplume  Grass  Poison   75      80       85      110
# 3   71             Victreebel  Grass  Poison   80     105       65      100
# 4  591              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Total  Generation  Legendary
# 0      100     80    525           1      False
# 1      120     80    625           1      False
# 2       90     50    490           1      False
# 3       70     70    490           1      False
# 4       80     30    464           5      False

# %% [markdown]
# ### *Exclude certain values*

# %%
no_mega = df.loc[~df['Name'].str.contains('Mega')] # ~ is not
no_mega
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Total  Generation  Legendary
# 0         65     45    318           1      False
# 1         80     60    405           1      False
# 2        100     80    525           1      False
# 4         50     65    309           1      False
# 5         65     80    405           1      False
# ..       ...    ...    ...         ...        ...
# 794       95     95    600           6       True
# 795      150     50    600           6       True
# 797      130     70    600           6       True
# 798      130     80    680           6       True
# 799       90     70    600           6       True
#
# [751 rows x 13 columns]

# %% [markdown]
# ### *Using REGEX*

# %%
import re

# Get fire or grass type
df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)] #flags=re.I is ignore case
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Total  Generation  Legendary
# 0         65     45    318           1      False
# 1         80     60    405           1      False
# 2        100     80    525           1      False
# 3        120     80    625           1      False
# 4         50     65    309           1      False
# ..       ...    ...    ...         ...        ...
# 735       54     72    369           6      False
# 736       66    106    507           6      False
# 740       57     52    350           6      False
# 741       81     68    531           6      False
# 799       90     70    600           6       True
#
# [122 rows x 13 columns]

# %%
# Get all names that start with pi
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# 578  519               Pidove    Normal    Flying   50      55       50
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# 20        35       35     56    251           1      False
# 21        50       50     71    349           1      False
# 22        70       70    101    479           1      False
# 23       135       80    121    579           1      False
# 30        50       50     90    320           1      False
# 136       55       70     85    500           1      False
# 137       65       90    105    600           1      False
# 186       35       35     60    205           2      False
# 219       35       35     15    290           2      False
# 239       60       60     50    450           2      False
# 438       61       56     40    314           4      False
# 558       70       55     55    418           5      False
# 578       36       30     43    264           5      False

# %% [markdown]
# ### *Change the name of Fire*

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Fire'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# 0         65       65     45    318           1      False
# 1         80       80     60    405           1      False
# 2        100      100     80    525           1      False
# 3        122      120     80    625           1      False
# 4         60       50     65    309           1      False
# ..       ...      ...    ...    ...         ...        ...
# 795      100      150     50    600           6       True
# 796      160      110    110    700           6       True
# 797      150      130     70    600           6       True
# 798      170      130     80    680           6       True
# 799      130       90     70    600           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ### *Make all Fire type pokemon legendary*

# %%
df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True
print(df)
df = pd.read_csv('/Users/vincentvogel/Desktop/new_me/Python/Pandas/basics/modified_pokemon_data.csv')
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# 0         65       65     45    318           1      False
# 1         80       80     60    405           1      False
# 2        100      100     80    525           1      False
# 3        122      120     80    625           1      False
# 4         60       50     65    309           1       True
# ..       ...      ...    ...    ...         ...        ...
# 795      100      150     50    600           6       True
# 796      160      110    110    700           6       True
# 797      150      130     70    600           6       True
# 798      170      130     80    680           6       True
# 799      130       90     70    600           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ### *You can change the values for multiple columns given a condition*

# %%
df.loc[df['Total'] > 500, ['Generation', 'Legendary']] = 'OH YEAH'
print(df)
df = pd.read_csv('/Users/vincentvogel/Desktop/new_me/Python/Pandas/basics/modified_pokemon_data.csv')
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total Generation Legendary
# 0         65       65     45    318          1     False
# 1         80       80     60    405          1     False
# 2        100      100     80    525    OH YEAH   OH YEAH
# 3        122      120     80    625    OH YEAH   OH YEAH
# 4         60       50     65    309          1     False
# ..       ...      ...    ...    ...        ...       ...
# 795      100      150     50    600    OH YEAH   OH YEAH
# 796      160      110    110    700    OH YEAH   OH YEAH
# 797      150      130     70    600    OH YEAH   OH YEAH
# 798      170      130     80    680    OH YEAH   OH YEAH
# 799      130       90     70    600    OH YEAH   OH YEAH
#
# [800 rows x 13 columns]

# %% [markdown]
# <br><br>
# ***
# <br>
# ## 7. Aggregate Statistics (Groupby)

# %% [markdown]
# ### *Get average stats for all types*

# %%
df.groupby(['Type 1']).mean()
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
#
Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       29    29      20   29      29       29       29       29     29
# Dragon     20    20       9   20      20       20       20       20     20
# Electric   40    40      14   40      40       40       40       40     40
# Fairy      16    16       2   16      16       16       16       16     16
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       47    47      20   47      47       47       47       47     47
# Flying      2     2       2    2       2        2        2        2      2
# Ghost      30    30      20   30      30       30       30       30     30
# Grass      67    67      35   67      67       67       67       67     67
# Ground     28    28      16   28      28       28       28       28     28
# Ice        22    22      10   22      22       22       22       22     22
# Normal     96    96      37   96      96       96       96       96     96
# Poison     28    28      13   28      28       28       28       28     28
# Psychic    43    43      14   43      43       43       43       43     43
# Rock       40    40      32   40      40       40       40       40     40
# Steel      23    23      19   23      23       23       23       23     23
# Water     108   108      52  108     108      108      108      108    108
#
#           Total  Generation  Legendary
# Type 1
# Bug          69          69         69
# Dark         29          29         29
# Dragon       20          20         20
# Electric     40          40         40
# Fairy        16          16         16
# Fighting     27          27         27
# Fire         47          47         47
# Flying        2           2          2
# Ghost        30          30         30
# Grass        67          67         67
# Ground       28          28         28
# Ice          22          22         22
# Normal       96          96         96
# Poison       28          28         28
# Psychic      43          43         43
# Rock         40          40         40
# Steel        23          23         23
# Water       108         108        108

# %% [markdown]
# <br>
# We can see that there is a lot of repeated values above, we can clean this up by doing
# the following:

# %%
df['count'] = 1 # this makes a column that is 1 for each row

df.groupby(['Type 1']).count()['count'] # This simply gives the count for type 1
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %% [markdown]
# ### *We can also subset this*

# %%
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# <br><br>
# ***
# <br>
# ## 8. Working With Large Amounts of Data

# %% [markdown]
# ### *chunksize*

# %%
#for df in pd.read_csv('/Users/vincentvogel/Desktop/new_me/Python/Pandas/basics/modified_pokemon_data.csv', chunksize=5):
    #print("**Chunk**")
    #print(df)

# %%
new_df = pd.DataFrame(columns=df.columns) # creates a new dataframe with the same column names

for df in pd.read_csv('/Users/vincentvogel/Desktop/new_me/Python/Pandas/basics/modified_pokemon_data.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    new_df = pd.concat([new_df, results])
new_df
# Out:
#          # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed Total  \
# Fire     1    1    NaN      0  1      1       1       1       1     1     1
# Grass    4    4    NaN      4  4      4       4       4       4     4     4
# Fire     4    4    NaN      3  4      4       4       4       4     4     4
# Water    1    1    NaN      0  1      1       1       1       1     1     1
# Bug      2    2    NaN      0  2      2       2       2       2     2     2
# ...     ..  ...    ...    ... ..    ...     ...     ...     ...   ...   ...
# Fairy    1    1    NaN      0  1      1       1       1       1     1     1
# Flying   2    2    NaN      2  2      2       2       2       2     2     2
# Fire     1    1    NaN      1  1      1       1       1       1     1     1
# Psychic  2    2    NaN      2  2      2       2       2       2     2     2
# Rock     2    2    NaN      2  2      2       2       2       2     2     2
#
#         Generation Legendary
# Fire             1         1
# Grass            4         4
# Fire             4         4
# Water            1         1
# Bug              2         2
# ...            ...       ...
# Fairy            1         1
# Flying           2         2
# Fire             1         1
# Psychic          2         2
# Rock             2         2
#
# [433 rows x 13 columns]
